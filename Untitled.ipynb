# %%
import pandas as pd

# %%
data=pd.read_csv("./Titanic.csv")

# %%
data
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
groupgender_survived = data.groupby(['Sex'])["Survived"].sum()

# %%
groupgender_survived
# Out:
# Sex
# female    233.0
# male      109.0
# Name: Survived, dtype: float64

# %%
grouppclass_survived = data.groupby(['Pclass'])["Survived"].sum()

# %%
grouppclass_survived
# Out:
# Pclass
# 1    136.0
# 2     87.0
# 3    119.0
# Name: Survived, dtype: float64

# %% [markdown]
# # Query

# %%
agesurv=data.query("Age == 24 & Survived == 1.0")

# %%
agesurv
# Out:
#      PassengerId  Survived  Pclass  \
# 127          128       1.0       3
# 142          143       1.0       3
# 247          248       1.0       2
# 310          311       1.0       1
# 316          317       1.0       2
# 341          342       1.0       1
# 345          346       1.0       2
# 369          370       1.0       1
# 394          395       1.0       3
# 437          438       1.0       2
# 600          601       1.0       2
# 615          616       1.0       2
# 641          642       1.0       1
# 710          711       1.0       1
# 858          859       1.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 127                          Madsen, Mr. Fridtjof Arne    male  24.0      0
# 142  Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...  female  24.0      1
# 247                    Hamalainen, Mrs. William (Anna)  female  24.0      0
# 310                     Hays, Miss. Margaret Bechstein  female  24.0      0
# ...

# %%
Sasthamkotta_board=data.query("Boarded == 'Southampton' ")

# %%
Sasthamkotta_board
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# 6               7       0.0       1
# ...           ...       ...     ...
# 1302         1303       NaN       1
# 1303         1304       NaN       3
# 1304         1305       NaN       3
# 1306         1307       NaN       3
# 1307         1308       NaN       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %%
Sasthamkotta_board
# Out:
#       PassengerId  Survived  Pclass  \
# 1               2       1.0       1
# 30             31       0.0       1
# 34             35       0.0       1
# 52             53       1.0       1
# 57             58       0.0       3
# ...           ...       ...     ...
# 1262         1263       NaN       1
# 1266         1267       NaN       1
# 1282         1283       NaN       1
# 1288         1289       NaN       1
# 1305         1306       NaN       1
#
#                                                    Name     Sex   Age  SibSp  \
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 30                             Uruchurtu, Don. Manuel E    male  40.0      0
# 34                              Meyer, Mr. Edgar Joseph    male  28.0      1
# 52             Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 57                                  Novel, Mr. Mansouer    male  28.5      0
# ...

# %%
Sasthamkotta_board = data.query("Boarded == 'Cherbourg' & Age > 25 ")

# %%
Sasthamkotta_board
# Out:
#       PassengerId  Survived  Pclass  \
# 1               2       1.0       1
# 30             31       0.0       1
# 34             35       0.0       1
# 52             53       1.0       1
# 57             58       0.0       3
# ...           ...       ...     ...
# 1262         1263       NaN       1
# 1266         1267       NaN       1
# 1282         1283       NaN       1
# 1288         1289       NaN       1
# 1305         1306       NaN       1
#
#                                                    Name     Sex   Age  SibSp  \
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 30                             Uruchurtu, Don. Manuel E    male  40.0      0
# 34                              Meyer, Mr. Edgar Joseph    male  28.0      1
# 52             Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 57                                  Novel, Mr. Mansouer    male  28.5      0
# ...

# %%
data.head(10)
# Out:
#       PassengerId  Survived  Pclass  \
# 845           846       0.0       3
# 1283         1284       NaN       3
# 746           747       0.0       3
# 279           280       1.0       3
# 1236         1237       NaN       3
# 948           949       NaN       3
# 308           309       0.0       2
# 874           875       1.0       2
# 1142         1143       NaN       3
# 899           900       NaN       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 845                         Abbing, Mr. Anthony    male  42.0      0      0
# 1283              Abbott, Master. Eugene Joseph    male  13.0      0      2
# 746                 Abbott, Mr. Rossmore Edward    male  16.0      1      1
# 279            Abbott, Mrs. Stanton (Rosa Hunt)  female  35.0      1      1
# 1236                Abelseth, Miss. Karen Marie  female  16.0      0      0
# 948               Abelseth, Mr. Olaus Jorgensen    male  25.0      0      0
# ...

# %%
death_or_alive=data.query(" Boarded == 'Southampton' & Age >25")

# %%
death_or_alive
# Out:
#       PassengerId  Survived  Pclass  \
# 845           846       0.0       3
# 279           280       1.0       3
# 365           366       0.0       3
# 401           402       0.0       3
# 40             41       0.0       3
# ...           ...       ...     ...
# 1227         1228       NaN       2
# 1151         1152       NaN       3
# 559           560       1.0       3
# 286           287       1.0       3
# 153           154       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 845                              Abbing, Mr. Anthony    male  42.0      0
# 279                 Abbott, Mrs. Stanton (Rosa Hunt)  female  35.0      1
# 365                   Adahl, Mr. Mauritz Nils Martin    male  30.0      0
# 401                                  Adams, Mr. John    male  26.0      0
# 40    Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# ...                                              ...     ...   ...    ...
# ...
